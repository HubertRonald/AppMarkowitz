# %%
from appmarkowitz.modules import markowitz, get_data
from appmarkowitz.utils.constants import Constants as CTE

# %%
# Assets:
assets = "DOV,DPZ,EBAY,FTNT,GIS,L,LDOS,MDLZ,QCOM,RJF,SEE,SHW,SLB,UDR,WELL,XOM".split(",")

# %%
df = get_data.get_closing_price(assets=assets)
# Out:
#                DOV     DPZ    EBAY    FTNT    GIS      L    LDOS   MDLZ  \
# date
# 2022-04-04  157.93  403.79  56.730  346.69  68.49  63.86  107.23  63.04
# 2022-04-05  153.92  391.17  56.400  341.89  69.16  63.30  107.20  63.01
# 2022-04-06  154.75  391.10  54.110  332.07  69.73  63.36  107.48  63.20
# 2022-04-07  154.43  397.40  54.380  338.12  69.75  63.56  108.07  62.89
# 2022-04-08  150.88  394.79  55.030  336.17  70.17  64.43  107.99  63.40
# ...            ...     ...     ...     ...    ...    ...     ...    ...
# 2023-03-28  144.33  324.23  42.870   64.27  84.77  55.88   91.10  69.59
# 2023-03-29  146.96  327.58  43.630   64.81  85.03  56.90   91.44  70.37
# 2023-03-30  148.15  327.65  43.910   65.81  84.96  57.30   91.59  69.58
# 2023-03-31  151.94  329.87  44.355   66.45  85.46  58.02   92.06  69.72
# 2023-04-03  150.52  332.52  44.280   66.31  85.92  57.59   93.20  70.22
#
#               QCOM     RJF    SEE     SHW    SLB    UDR   WELL     XOM
# date
# ...
